# %%
import json
import random

# %%
def load_topic_tree(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        topic_tree = json.load(f)
    return topic_tree

# Load Music topic
music_topic = load_topic_tree('../data/music.json')
science_topic = load_topic_tree('../data/science.json')
sports_topic = load_topic_tree('../data/sports.json')
politics_topic = load_topic_tree('../data/politics.json')
health_topic = load_topic_tree('../data/health.json')
movies_topic = load_topic_tree('../data/movies.json')
gaming_topic = load_topic_tree('../data/gaming.json')

# %% [markdown]
# # Appendix -- Topic hierarchy

# %% [markdown]
# ```
# Music
# ├── Genres
# │   ├── Rock
# │   │   ├── Classic Rock
# │   │   │   ├── 70s Rock
# │   │   │   └── 80s Rock
# │   │   └── Alternative Rock
# │   │       ├── Grunge
# │   │       └── Indie Rock
# │   ├── Pop
# │   │   ├── Electropop
# │   │   │   ├── Synth-pop
# │   │   │   └── Dance Pop
# │   │   └── K-Pop
# │   │       ├── Boy Bands
# │   │       └── Girl Groups
# │   └── Jazz
# │       ├── Bebop
# │       └── Smooth Jazz
# ├── Artists
# │   ├── Singers
# │   │   ├── Solo Artists
# │   │   │   ├── Pop Singers
# │   │   │   └── Rock Singers
# │   │   └── Bands
# │   │       ├── Rock Bands
# │   │       └── Jazz Bands
# │   ├── Composers
# │   │   ├── Classical Composers
# │   │   └── Film Composers
# │   └── Producers
# │       ├── Record Producers
# │       └── Sound Engineers
# └── Instruments
#     ├── String Instruments
#     │   ├── Guitar
#     │   └── Violin
#     ├── Keyboard Instruments
#     │   ├── Piano
#     │   └── Synthesizer
#     └── Percussion Instruments
#         ├── Drums
#         └── Xylophone
# ```

# %% [markdown]
# ```
# Science
# ├── Biology
# │   ├── Genetics
# │   │   ├── Molecular Genetics
# │   │   └── Population Genetics
# │   ├── Ecology
# │   │   ├── Marine Ecology
# │   │   └── Conservation Ecology
# │   └── Microbiology
# │       ├── Bacteriology
# │       └── Virology
# ├── Physics
# │   ├── Quantum Mechanics
# │   │   ├── Quantum Computing
# │   │   └── Quantum Optics
# │   ├── Classical Mechanics
# │   │   ├── Fluid Mechanics
# │   │   └── Rigid Body Dynamics
# │   └── Astrophysics
# │       ├── Cosmology
# │       └── Stellar Physics
# ├── Chemistry
# │   ├── Organic Chemistry
# │   │   ├── Synthesis
# │   │   └── Medicinal Chemistry
# │   ├── Inorganic Chemistry
# │   │   ├── Coordination Chemistry
# │   │   └── Solid-State Chemistry
# │   └── Biochemistry
# │       ├── Enzymology
# │       └── Metabolism
# └── Computer Science
#     ├── Artificial Intelligence
#     │   ├── Machine Learning
#     │   └── Natural Language Processing
#     ├── Software Engineering
#     │   ├── Agile Methodologies
#     │   └── DevOps
#     └── Data Science
#         ├── Data Mining
#         └── Data Visualization
# ```

# %% [markdown]
# ```
# Sports
# ├── Team Sports
# │   ├── Football
# │   │   ├── American Football
# │   │   │   ├── NFL
# │   │   │   └── College Football
# │   │   └── Soccer
# │   │       ├── FIFA World Cup
# │   │       └── UEFA Champions League
# │   └── Basketball
# │       ├── NBA
# │       └── College Basketball
# ├── Individual Sports
# │   ├── Tennis
# │   │   ├── Grand Slam Tournaments
# │   │   └── ATP/WTA Tours
# │   └── Athletics
# │       ├── Track Events
# │       └── Field Events
# ├── Extreme Sports
# │   ├── Skateboarding
# │   │   ├── Street Skateboarding
# │   │   └── Park Skateboarding
# │   └── Rock Climbing
# │       ├── Bouldering
# │       └── Sport Climbing
# └── Sports Science
#     ├── Kinesiology
#     │   ├── Biomechanics
#     │   └── Exercise Physiology
#     ├── Sports Medicine
#     │   ├── Injury Prevention
#     │   └── Rehabilitation
#     └── Sports Analytics
#         ├── Player Performance Metrics
#         └── Game Strategy Optimization
#
# ```

# %% [markdown]
# ```
# Politics
# ├── International
# │   ├── Diplomacy
# │   │   ├── Bilateral Diplomacy
# │   │   └── Multilateral Diplomacy
# │   ├── International Relations
# │   │   ├── Conflict Resolution
# │   │   └── Global Governance
# │   └── Foreign Policy
# │       ├── Trade Policy
# │       └── Defense Policy
# ├── Domestic
# │   ├── Elections
# │   │   ├── Presidential Elections
# │   │   └── Local Elections
# │   ├── Legislation
# │   │   ├── Law Making Process
# │   │   └── Policy Development
# │   └── Governance
# │       ├── Executive Branch
# │       └── Legislative Branch
# ├── Political Theory
# │   ├── Democracy
# │   │   ├── Representative Democracy
# │   │   └── Direct Democracy
# │   ├── Authoritarianism
# │   │   ├── Dictatorships
# │   │   └── One-Party States
# │   └── Political Ideologies
# │       ├── Liberalism
# │       └── Conservatism
# └── Public Administration
#     ├── Public Management
#     │   ├── Strategic Management
#     │   └── Performance Management
#     ├── Policy Implementation
#     │   ├── Policy Execution
#     │   └── Program Evaluation
#     └── E-Government
#         ├── Digital Governance
#         └── Telemedicine
#
# ```

# %% [markdown]
# ```
# Health
# ├── Nutrition
# │   ├── Diets
# │   │   ├── Vegetarian Diets
# │   │   └── Keto Diets
# │   ├── Vitamins
# │   │   ├── Vitamin C
# │   │   └── Vitamin D
# │   └── Supplements
# │       ├── Protein Supplements
# │       └── Omega-3 Supplements
# ├── Fitness
# │   ├── Exercise
# │   │   ├── Cardiovascular Exercise
# │   │   └── Strength Training
# │   ├── Yoga
# │   │   ├── Hatha Yoga
# │   │   └── Vinyasa Yoga
# │   └── Fitness Equipment
# │       ├── Free Weights
# │       └── Treadmills
# ├── Mental Health
# │   ├── Counseling
# │   │   ├── Marriage Counseling
# │   │   └── Career Counseling
# │   ├── Therapy
# │   │   ├── Cognitive Behavioral Therapy (CBT)
# │   │   └── Art Therapy
# │   └── Mental Disorders
# │       ├── Anxiety Disorders
# │       └── Mood Disorders
# ├── Public Health
# │   ├── Epidemiology
# │   │   ├── Infectious Disease Epidemiology
# │   │   └── Chronic Disease Epidemiology
# │   ├── Health Policy
# │   │   ├── Healthcare Reform
# │   │   └── Mental Health Policy
# │   └── Global Health
# │       ├── Disease Prevention
# │       └── Vaccine Development
# └── Medical Research
#     ├── Clinical Trials
#     │   ├── Phase I Trials
#     │   └── Phase II Trials
#     ├── Biomedical Research
#     │   ├── Genetic Research
#     │   └── Neurobiology Research
#     └── Public Health Research
#         ├── Epidemiological Studies
#         └── Health Policy Research
# ```

# %% [markdown]
# ```
# Movies
# ├── Genres
# │   ├── Action
# │   │   ├── Superhero Action
# │   │   │   ├── Marvel Cinematic Universe
# │   │   │   └── DC Extended Universe
# │   │   └── Martial Arts Action
# │   │       ├── Kung Fu Films
# │   │       └── Taekwondo Films
# │   ├── Comedy
# │   │   ├── Romantic Comedy
# │   │   │   └── Screwball Comedy
# │   │   └── Dark Comedy
# │   │       └── Black Humor Films
# │   ├── Drama
# │   │   ├── Historical Drama
# │   │   │   └── Biographical Films
# │   │   └── Medical Drama
# │   │       └── Hospital Dramas
# │   ├── Horror
# │   │   ├── Psychological Horror
# │   │   │   └── Mind Horror
# │   │   └── Supernatural Horror
# │   │       └── Ghost Films
# │   └── Science Fiction
# │       ├── Cyberpunk
# │       │   └── Dystopian Cyberpunk
# │       └── Space Opera
# │           └── Epic Space Battles
# ├── Directors
# │   ├── Blockbuster Directors
# │   │   ├── Steven Spielberg
# │   │   └── James Cameron
# │   ├── Indie Directors
# │   │   ├── Wes Anderson
# │   │   └── Greta Gerwig
# │   ├── Documentary Directors
# │   │   ├── Michael Moore
# │   │   └── Ken Burns
# │   └── Foreign Language Directors
# │       ├── Pedro Almodóvar
# │       └── Guillermo del Toro
# ├── Actors
# │   ├── Lead Actors
# │   │   ├── A-list Actors
# │   │   └── Rising Stars
# │   ├── Supporting Actors
# │   │   └── Character Actors
# │   ├── Actresses
# │   │   ├── Leading Actresses
# │   │   └── Supporting Actresses
# │   └── Voice Actors
# │       └── Animation Voice Actors
# ├── Film Production
# │   ├── Screenwriting
# │   │   └── Script Development
# │   ├── Cinematography
# │   │   └── Camera Techniques
# │   ├── Editing
# │   │   └── Digital Editing
# │   └── Sound Design
# │       └── Foley Artistry
# ├── Film Distribution
# │   ├── Theatrical Distribution
# │   │   └── Major Theaters
# │   ├── Digital Distribution
# │   │   └── Streaming Services
# │   └── Film Festivals
# │       └── Cannes Film Festival
# └── Film Criticism
#     ├── Film Reviews
#     │   └── Professional Criticism
#     ├── Film Theory
#     │   └── Auteur Theory
#     ├── Box Office Analysis
#     │   └── Revenue Tracking
#     └── Film Awards
#         └── Academy Awards (Oscars)
#
# ```

# %% [markdown]
# ```
# Gaming
# ├── Platforms
# │   ├── PC Gaming
# │   │   ├── Steam
# │   │   └── Epic Games Store
# │   ├── Console Gaming
# │   │   ├── PlayStation
# │   │   └── Xbox
# │   └── Mobile Gaming
# │       ├── iOS Games
# │       └── Android Games
# ├── Game Development
# │   ├── Indie Game Development
# │   │   └── Solo Developers
# │   ├── AAA Game Development
# │   │   └── Large Studios
# │   └── VR Game Development
# │       └── Oculus Rift Games
# ├── eSports
# │   ├── Competitive Gaming
# │   │   └── League of Legends
# │   └── Streaming
# │       └── Twitch Streaming
# ├── Gaming Communities
# │   ├── Online Forums
# │   │   └── Reddit Communities
# │   └── Discord Servers
# │       └── Gaming Subreddits
# └── eSports Events
#     ├── Major Tournaments
#     │   └── The International
#     └── Online Tournaments
#         └── LAN Events
# ```
